# %%
from z2chain.circs import SecondOrderTrotter
L = 6
qc = SecondOrderTrotter(L, 1, 0.05, 0.7, 1, 1)
qc.draw(output="mpl", filename="second_order_trotter.pdf")

# %%
from z2chain.circs import SecondOrderTrotterOld
L = 6
qc = SecondOrderTrotterOld(L, 1, 0.05, 0.7, 1, 1)
qc.draw(output="mpl", filename="second_order_trotter_old.pdf")

# %%
from z2chain.circs import SecondOrderTrotter
L = 6
qc = SecondOrderTrotter(L, 1, 0.05, 0.7, 1, 1, 10)
qc.draw(output="mpl", filename="second_order_trotter_gauge.pdf")

# %%
from z2hex.circs import SecondOrderTrotter
from z2hex.geometry import HeavyHexLattice

lattice = HeavyHexLattice(1, 2)
qc = SecondOrderTrotter(lattice, 1, 1, 1, 1, 1, 1)
qc.draw(output="mpl", filename="2d_trotter_layer.pdf")

# %%
lattice.plot_lattice(number_qubits=True)

# %%
from utils.circs import depth2qb
depth2qb(qc)
# Out:
# 6
